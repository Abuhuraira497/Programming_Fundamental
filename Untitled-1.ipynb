# %%
# variables
my_book = ("pak study")
print("before changing: ",my_book)

#change the value of varibale
my_book = "science"
print ("after changing: ",my_book)
# Out:
# before changing:  pak study
# after changing:  science

# %%
name = "ali"
print (name)
#replace the value of name
name = "ahmad"
print(name)
# Out:
# ali
# ahmad

# %%
#different data types
age = 22 #intiger
temprature = 36.5  #float
name= "Abu huuraira" #string
is_student = True #boolean
has_passed = False #boolean

print("age: ", age, type(age))
print("temprature: ", temprature, type(temprature))
print("name: ",name, type(name))
print("is_student: ", is_student, type(is_student))
print("has passed: ", has_passed, type(has_passed))
# Out:
# age:  22 <class 'int'>
# temprature:  36.5 <class 'float'>
# name:  Abu huuraira <class 'str'>
# is_student:  True <class 'bool'>
# has passed:  False <class 'bool'>

# %%
#mixing data types
#addition
apple = 5
oranges = 10
total_fruits = apple + oranges
print (total_fruits)

# joining strings 
first = "abu"
second = "huraira"

my_name = first+ " "+ second
print (my_name)
# Out:
# 15
# abu huraira

# %%
#mixing data types
#adding strings and integers
number = 5
text = "3"
result = number +int (text) #number + text # this cause an error
print (result)
# Out:
# 8
# 5

# %%
#changing variables throughout the program
money = 0
print ("i have ", money,"$")
money = money + 100 #money += 100 
print ("i have ", money , "$")
money = money - 30 #money -= 30
print ( 'i have ',money , "$")
# Out:
# i have  0 $
# i have  100 $
# i have  70 $

# %%
#print variable all togather
name = " abu huraira"
age = 22
city = "peshawar"

print(name, age, city)
# Out:
#  abu huraira 22 peshawar

# %%
#making print look pretty f-string
# put f just before opening quotes and put variable inside the curly braces
name = " abu huraira"
age = 22
city = "peshawar"
print(f"My name is {name} and I am {age} years old. i am from {city}.")
# Out:
# My name is  abu huraira and I am 22 years old. i am from peshawar.

# %%
#print special features
print("first ")
print ("second ")
#by default prints end with new line (like pressing enter)

print("first", end=" ")
print("second")
print("apple","banana","orange", sep =",")#what goes between multiple items
print("apple", "banana", "orange",sep= " | ")
# Out:
# first
# second
# first second
# apple,banana,orange
# apple | banana | orange

# %%
#getting input from user
input("what is your name")

#storing input in variable
name = input("Enter your name")
print(f"hello {name}!")
# Out:
# hello abuhuraira!

# %%
#input()always give you text/string
age = input("how old are you")
print(age)
print(type(age))

# next_age = age +1 #this will cause error. can't add number to string
# Out:
# 23
# <class 'str'>

# %%
age_text=input("enter age ")
#converting srting into integer

age_number =int(age_text)
age_number = age_number + 1
print (age_number)
# Out:
# 24

# %%
#we can get input what datatype we want just put datatype before input.
#otherwise it will get an input as a string
number = int(input("Enter a number"))
print(number)
# Out:
# 23

# %%
#different datatype conversion
count= int(input ("enter a number"))
print(type(number), number)

price = float(input("Enter the price"))
print(type(price), price)

name= (input("enter name")) #by default it takes string value
print(type(name), name)
# Out:
# <class 'int'> 23
# <class 'float'> 12.0
# <class 'str'> 12
